# %% [markdown]
# # <span style="color:#c8a2c8; font-weight:bold">Irene's visuals notebook</span>

# %%
# imports configuration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
from IPython.display import display, HTML

# forcing pandas to display whole url
pd.set_option('display.max_colwidth', None)

# pforcing pandas to display all the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# path to final cleaned dataset in data/cleaned
CLEANED_CSV_PATH = "../data/cleaned/properties_final_irene.csv"

# reading the file
data_df = pd.read_csv(CLEANED_CSV_PATH)

# checking dataset
data_df.describe(include='all')
# Out:
#        property_type property_subtype         price  living_area_m2      bedrooms     bathrooms          address   postal_code   city      latitude     longitude  building_year state_of_the_building     furnished    has_garage  parking_count kitchen_equipped  has_elevator      facades  floors_total    has_garden  garden_area_m2   has_terrace  total_area_m2 epc_score    region province nearby_city  km_from_nearby_city  is_nearby_city_prestigious  floor_number                                                              property_url coord_swapped  price_per_m2
# count          12622            12622  1.239900e+04    11769.000000  12203.000000  11240.000000            10109  12622.000000  12622  12620.000000  12620.000000    7589.000000                  9717  12622.000000  12622.000000    4325.000000             3436  12622.000000  9514.000000   5674.000000  12622.000000     2835.000000  12622.000000    7040.000000     10614     12622    12622       12620         12620.000000                12620.000000   3556.000000                                                                     12622         12622  11557.000000
# unique             2               15           NaN             NaN           NaN           NaN             9526           NaN   1612           NaN           NaN            NaN                     8           NaN           NaN            NaN                4           NaN          NaN           NaN           NaN             NaN           NaN            NaN        11         3       11          44                  NaN                         NaN           NaN                                                                     12611             2           NaN
# top            House        residence           NaN             NaN           NaN           NaN  Dessauerplein 1           NaN  Liege           NaN           NaN            NaN                Normal           NaN           NaN            NaN   Fully equipped           NaN          NaN           NaN           NaN             NaN           NaN            NaN         C  Wallonia    Liège   Bruxelles                  NaN                         NaN           NaN  https://immovlan.be/en/detail/residence/for-sale/7080/noirchain/vbe33505         False           NaN
# freq            8184             6630           NaN             NaN           NaN           NaN               33           NaN    271           NaN           NaN            NaN                  3730           NaN           NaN            NaN             1626           NaN          NaN           NaN           NaN             NaN           NaN            NaN      2131      6102     1743        1393                  NaN                         NaN           NaN                                                                         2         12575           NaN
# mean             NaN              NaN  3.994536e+05      175.053191      3.087683      1.418149              NaN   5032.892252    NaN     50.718773      4.551145    1970.154171                   NaN      0.035969      0.453335       1.855491              NaN      0.193630     2.965209      3.308072      0.538583     1254.042328      0.660196    1612.671023       NaN       NaN      NaN         NaN            36.519525                    0.062678      3.524466                                                                       NaN           NaN   2579.397854
# std              NaN              NaN  3.708000e+05      159.945498      2.278082      1.178397              NaN   2674.674974    NaN      0.373565      0.820485      47.370657                   NaN      0.186220      0.497837      28.904444              NaN      0.395158     0.879917      2.922330      0.498529     5444.541437      0.473661    5256.253362       NaN       NaN      NaN         NaN           398.131055                    0.242393     29.065419                                                                       NaN           NaN   1397.459709
# min              NaN              NaN  1.990000e+04       12.000000      1.000000      1.000000              NaN   1000.000000    NaN     49.506790      2.509162    1500.000000                   NaN      0.000000      0.000000       1.000000              NaN      0.000000     1.000000      1.000000      0.000000        1.000000      0.000000       1.000000       NaN       NaN      NaN         NaN             0.000000                    0.000000      0.000000                                                                       NaN           NaN    106.000000
# 25%              NaN              NaN  1.950000e+05       90.000000      2.000000      1.000000              NaN   2580.000000    NaN     50.469982      4.149293    1950.000000                   NaN      0.000000      0.000000       1.000000              NaN      0.000000     2.000000      2.000000      0.000000      117.000000      0.000000     270.000000       NaN       NaN      NaN         NaN             3.200000                    0.000000      1.000000                                                                       NaN           NaN   1702.000000
# 50%              NaN              NaN  3.025000e+05      145.000000      3.000000      1.000000              NaN   4990.000000    NaN     50.771583      4.465059    1975.000000                   NaN      0.000000      0.000000       1.000000              NaN      0.000000     3.000000      3.000000      1.000000      357.000000      1.000000     636.000000       NaN       NaN      NaN         NaN             8.500000                    0.000000      2.000000                                                                       NaN           NaN   2400.000000
# 75%              NaN              NaN  4.990000e+05      208.000000      4.000000      2.000000              NaN   7100.000000    NaN     51.009027      5.244037    2007.000000                   NaN      0.000000      1.000000       1.000000              NaN      0.000000     4.000000      4.000000      1.000000      930.000000      1.000000    1345.250000       NaN       NaN      NaN         NaN            17.200000                    0.000000      3.000000                                                                       NaN           NaN   3158.000000
# max              NaN              NaN  1.300000e+07     3990.000000    100.000000     71.000000              NaN   9991.000000    NaN     51.471380      6.353742    2026.000000                   NaN      1.000000      1.000000    1885.000000              NaN      1.000000     8.000000     30.000000      1.000000   150000.000000      1.000000  178367.000000       NaN       NaN      NaN         NaN          6681.300000                    1.000000    999.000000                                                                       NaN           NaN  26043.000000

# %% [markdown]
# ## <span style="color:#c8a2c8">1. Data Volume and Integrity</span>

# %% [markdown]
# ### **Q1**: How many observations and features/columns do you have?

# %% [markdown]
# *Our strategy is based on a dataset which includes more than 12600 properties across Belgium.*

# %% [markdown]
# ### **Q2**: What is the proportion of missing values per column?

# %%
print("="*30 + " DATASET STRUCTURE " + "="*30)
print("\n")
print(f"Number of (motionless) observations: {data_df.shape[0]}\n")
print(f"Number of properties features (columns): {data_df.shape[1]}\n")
print("\n")

print("="*30 + " MISSING VALUES " + "="*30)
print("\n")
# calculation of the proportion of missing values
missing_prop = (data_df.isnull().sum() / len(data_df)) * 100
missing_prop = missing_prop[(missing_prop > 0)].sort_values(ascending=False)
print(f"Percentage of missing values for each column:")
print("\n")
display(missing_prop)
print("\n")

# visual
plt.figure(figsize=(10,6))
sns.barplot(
    x=missing_prop.values, 
    y=missing_prop.index, 
    palette="viridis"
)
plt.title(
    "Proportion of Missing Values per Column (%)",
    fontsize=14,
    pad=15)
# Out:
#   Cell In[32], line 26
#     fontsize=)
#     ^
# SyntaxError: expected argument value expression

# %% [markdown]
# ## <span style="color:#c8a2c8">2. Bonus Insights</span>
